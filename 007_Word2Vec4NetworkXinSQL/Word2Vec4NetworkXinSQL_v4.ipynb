# %% [markdown]
# 教授にプレゼン後、データの保存をし、テーブルとして値を持つ必要があることがわかった
# 大きなデータになるので保存方法を考慮する必要があった。
# CSV、Excel、バイナリ、HDF5が候補として挙がった。
# HDF5形式は大容量のデータセットを効率的に保存するためのファイル形式であるため、採択。
# 参考サイトの少なさから一時的にSQLを採択
# SQLをテストし、全語句のデータの保存をしてみた
# SQLでは、VisualStudioCodeの拡張機能が使いづらく、SQLite3に変更した
# SQLite->dataframe->変更->dataframe->変更を保存->SQLiteの完成
# 上記の方法では変更件数に関わらず、全件で1分30秒かかる。
# 変更に時間がかかりすぎな点が課題であるため、データの更新方法を検討
# SQLからPythonに値を渡さず、直接書き込むことで一件当たり0.1秒以内
# また、拡散ネットワークを作るために、関連文字列に拡散し、ループ一回を拡散と見なしたとき、一回目の入力を除き、n=3の時、1、3、9、27、81、243

# %%
import pandas as pd
from gensim.models import Word2Vec
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import japanize_matplotlib
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# 学習済みモデルのロード
model_file_path = '../../KITERETU/gw2v160.model'
model = Word2Vec.load(model_file_path)

# %%
import pandas as pd
import sqlite3
import itertools

conn = sqlite3.connect('database.sqlite')
df = pd.read_sql_query("SELECT * FROM words", conn)

ans = []
ans.append([input("意味類似度ネットワークを作りたい単語を入力してください===>")])
print(ans)

for i in range(5):
    ans.append([])
    for j in range(len(ans[i])):
        out = model.wv.most_similar(positive=[ans[i][j]], topn=3)
        for prefecture, value in out:
            ans[i+1].append(prefecture)

print(ans)
for i in range(len(ans)):
    print(len(ans[i]))
        # 似ている単語TOP3を書き出す
        # out = model.wv.most_similar(positive=[ans[i][j]], topn=3)
        # ans配列にそれぞれ追加していく。
        # 出力例ans = [["群馬"],["群馬県","栃木","前橋"],["栃木県","埼玉県","長野県","群馬","栃木県","宇都宮","高崎","群馬","館林"]]

#結果としては、下記のような配列ができ上がる。

#         for prefecture, value in out:
#             ans[i].append(prefecture)

# print(ans)

        # # AtCoderでよく使う辞書処理を使って県と数値を取り出す
        # similar_words = [input_str]
        # for prefecture, value in out:
        #     print(prefecture, "\t", value)
        #     similar_words.append(prefecture)

        #     existing_indices = df[df[0] == prefecture].index
        #     existing_row = df.loc[existing_indices[0]]
        #     existing_row[1].extend([value])
        #     df.loc[existing_indices[0]] = existing_row
        #     # データの更新を行う
        #     #cursor.execute("UPDATE words SET value = ? WHERE word = ?", (0.10000, '其の'))


#print(df)
# Out:
# [['群馬']]
# [['群馬'], ['群馬県', '栃木', '前橋'], ['栃木県', '埼玉県', '長野県', '群馬', '栃木県', '宇都宮', '高崎', '群馬', '館林'], ['群馬県', '茨城県', '埼玉県', '群馬県', '神奈川県', '千葉県', '群馬県', '山梨県', '松本市', '群馬県', '栃木', '前橋', '群馬県', '茨城県', '埼玉県', '那須', '鹿沼', '栃木', '前橋', '伊勢崎', '群馬', '群馬県', '栃木', '前橋', '伊勢崎', '前橋', '川越'], ['栃木県', '埼玉県', '長野県', '千葉県', '栃木県', '茨城', '群馬県', '神奈川県', '千葉県', '栃木県', '埼玉県', '長野県', '千葉県', '東京都', '埼玉県', '神奈川県', '茨城県', '埼玉県', '栃木県', '埼玉県', '長野県', '山梨', '長野県', '静岡県', '長野市', '安曇野市', '塩尻市', '栃木県', '埼玉県', '長野県', '群馬', '栃木県', '宇都宮', '高崎', '群馬', '館林', '栃木県', '埼玉県', '長野県', '千葉県', '栃木県', '茨城