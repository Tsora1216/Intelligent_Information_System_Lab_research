# %% [markdown]
# https://zero-cheese.com/9349/

# %%
# !pip install torch diffusers transformers scipy ftfy

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

hugging_token = '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'

ldm = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4",
                                              revision="fp16",
                                              torch_dtype=torch.float16,
                                              use_auth_token=hugging_token
                                              ).to("cuda")

prompt = '神'

# 1000枚画像を作りたい場合
num_images = 10
for j in range(num_images):
    with autocast("cuda"):
        image = ldm(prompt).images[0] # 500×500px画像が生成
        # 画像サイズを変更したい場合
        # image = ldm(prompt, height=400, width=400).images[0]

    # save images (本コードでは、直下に画像が生成されていきます。)
    image.save(f"./image_{i}.png")
# Out:
# Downloading (…)on_pytorch_model.bin: 100%|██████████| 1.72G/1.72G [03:37<00:00, 7.91MB/s]
# Fetching 19 files:  79%|███████▉  | 15/19 [03:37<00:58, 14.52s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# g:\Intelligent_Information_System_Lab_research\011_research_Stable_Diffusion\research_Stable-Diffusion_v2.ipynb セル 2 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from diffusers import StableDiffusionPipeline
#       <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> hugging_token = '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'
# ----> <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> ldm = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4",
#       <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>                                               revision="fp16",
#       <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>                                               torch_dtype=torch.float16,
#      <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a>                                               use_auth_token=hugging_token
#      <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>                                               ).to("cuda")
#      <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> prompt = '神'
#      <a href='vscode-notebook-cell:/g%3A/Intelligent_Information_System_Lab_research/011_research_Stable_Diffusion/research_Stable-Diffusion_v2.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> # 1000枚画像を作りたい場合
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\pipeline_utils.py:154, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     151 # 1. Download the checkpoints and configs
#     152 # use snapshot download here to get it working from from_pretrained
#     153 if not os.path.isdir(pretrained_model_name_or_path):
# --> 154     cached_folder = snapshot_download(
#     155         pretrained_model_name_or_path,
#     156         cache_dir=cache_dir,
#     157         resume_download=resume_download,
#     158         proxies=proxies,
#     159         local_files_only=local_files_only,
#     160         use_auth_token=use_auth_token,
#     161         revision=revision,
#     162     )
#     163 else:
#     164     cached_folder = pretrained_model_name_or_path
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_validators.py:120, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     117 if check_use_auth_token:
#     118     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 120 return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\_snapshot_download.py:239, in snapshot_download(repo_id, revision, repo_type, cache_dir, local_dir, local_dir_use_symlinks, library_name, library_version, user_agent, proxies, etag_timeout, resume_download, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class)
#     237         _inner_hf_hub_download(file)
#     238 else:
# --> 239     thread_map(
#     240         _inner_hf_hub_download,
#     241         filtered_repo_files,
#     242         desc=f"Fetching {len(filtered_repo_files)} files",
#     243         max_workers=max_workers,
#     244         # User can use its own tqdm class or the default one from `huggingface_hub.utils`
#     245         tqdm_class=tqdm_class or hf_tqdm,
#     246     )
#     248 if local_dir is not None:
#     249     return str(os.path.realpath(local_dir))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tqdm\contrib\concurrent.py:94, in thread_map(fn, *iterables, **tqdm_kwargs)
#      80 """
#      81 Equivalent of `list(map(fn, *iterables))`
#      82 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)
#      91     [default: max(32, cpu_count() + 4)].
#      92 """
#      93 from concurrent.futures import ThreadPoolExecutor
# ---> 94 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tqdm\contrib\concurrent.py:76, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      74     map_args.update(chunksize=chunksize)
#      75 with PoolExecutor(**pool_kwargs) as ex:
# ---> 76     return list(tqdm_class(ex.map(fn, *iterables, **map_args), **kwargs))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tqdm\std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Program Files\Python310\lib\concurrent\futures\_base.py:609, in Executor.map.<locals>.result_iterator()
#     606 while fs:
#     607     # Careful not to keep a reference to the popped future
#     608     if timeout is None:
# --> 609         yield fs.pop().result()
#     610     else:
#     611         yield fs.pop().result(end_time - time.monotonic())
#
# File c:\Program Files\Python310\lib\concurrent\futures\_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File c:\Program Files\Python310\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
