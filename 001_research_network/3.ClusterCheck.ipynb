# %%
#密度（張ることができるリンクのうちのくらいの割合張られているか）
#辺の数/ペア->-2/3,3/3=1のようなもの

#クラスタ係数（隣接ノード同士がどのくらいつながっているか
#出てきた三角形の数/ペア→2/6

# %%
# %matplotlib inline
import networkx as nx # NetworkXをインポート
import matplotlib.pyplot as plt
import numpy as np

# ネットワーク生成
G = nx.Graph([(1, 2), (1,3), (1,4), (1,5), (3, 4), (4,5), (4,6),(5,6)])
nx.draw(G, with_labels=True) # ラベルをTrueにして番号の可視化

# %%
print(nx.average_clustering(G))
# Out:
# 0.5833333333333334
